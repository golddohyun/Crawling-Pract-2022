# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

# %%
result_list = []

## 01. json 파일 요청
headers = {'user-agent' :'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36'}

for i in range (1,11) : 
    url= f'https://news.naver.com/main/mainNews.naver?sid1=101&date=%2000:00:00&page={i}'
    httpresponse = requests.get(url, headers=headers)

    ## 02. json -> dict 형식으로 반환
    #news = json.loads(httpresponse.text)
    news = httpresponse.json()
    result = json.loads(news['airsResult'])['result']['101']
    
    ## 03. 변환된 list의 요소를 result_list에 추가 (extend 함수 or 연산자 +=)
    result_list.extend(result)

## 04. 뉴스 제목 추출 후 출력
for idx, title in enumerate(result_list, 1) :
    print(f"{idx}. {title['title']}")
# Out:
# 1. 오늘부터 최대 1000만원 손실보전금 지급, 신청 방법은?
# 2. 매출 감소 매장 371만곳에 손실보전금 23조원 지급
# 3. 손실보전금 180만명 동시 신청 가능…소진공 휴일 비상근무
# 4. 손실보전 최대 1000만원…"오늘 12시 안내문자, 오후 3시부터 지급"
# 5. 생애 첫 내집 마련 집값의 '80%' 대출… 청년 미래소득 확대반영 (상보)
# 6. 1주택 보유세 재작년 수준으로…50년 초장기 모기지 출시
# 7. 대신증권 "코스피 현재 극심한 저평가 영역…안도 랠리 전망"
# 8. LG 6%대 급등…자사주 5000억원 매입 효과
# 9. 매머드급 대단지, ‘신풍역 신동아 파밀리에’ 다양한 커뮤니티 시설 눈길
# 10. 칸 수상에 거리두기 해제 '겹호재'…CJ ENM 강세
# 11. "없어서 못판다"...효성첨단소재, 50만원선 '탈환'
# 12. "하방 막혔다"..LG, 자사주 취득 소식에 강세
# 13. HLB, 리보세라닙 발표 앞두고 급락 후 반등
# 14. [현장연결] 정부 "돼지고기·식용유·커피 등 연말까지 관세 면제"
# 15. 기아, 첫 PBV '니로 플러스' 출시…12일간 8천대 사전계약
# 16. "국내증시 극심한 저평가…2,700 기술적 반등"
# 17. 아이윈, 빗썸 투자 유치...양자암호 핵심부품 및 세계최초 공진 기술사 인수
# 18. ‘저금리로 대출 갈아타볼까’…핀다, 업계 최초 대환보장제 실시
# 19. "보험금 나오는 거 맞죠?"… 4세대 실손, 보상은 '함흥차사'
# 20. 연말까지 자동차 개소세 30% 인하…7월 저소득층 최대 100만 원 지원
# 21. 아이윈, 빗썸 투자 유치...양자암호 핵심부품 및 세계최초 공진 기술사 인수
# 22. ‘저금리로 대출 갈아타볼까’…핀다, 업계 최초 대환보장제 실시
# 23. "보험금 나오는 거 맞죠?"… 4세대 실손, 보상은 '함흥차사'
# 24. 연말까지 자동차 개소세 30% 인하…7월 저소득층 최대 100만 원 지원
# ...
