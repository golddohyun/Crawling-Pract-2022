# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from time import sleep

# %%
title_list = []

## 05. 뉴스 element 추출 함수 메서드 정의
def crawl_title() :
    global title_list
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    news_title = driver.find_elements(by=By.CSS_SELECTOR, value ='#section_body dt:nth-child(2) a')
    title_list += news_title

# %%
## 01. 네이버 홈페이지 접속
driver = webdriver.Chrome()
url = 'https://www.naver.com'
driver.get(url)
sleep(3)

## 02. 뉴스 탭 클릭
news_tab = '//*[@id="NM_FAVORITE"]/div[1]/ul[2]/li[2]/a'
driver.find_element(by=By.XPATH, value=news_tab).click()
sleep(2)

## 03. 경제 탭 클릭
econ_tab = '/html/body/section/header/div[2]/div/div/div[1]/div/div/ul/li[3]/a'
driver.find_element(by=By.XPATH, value=econ_tab).click()
sleep(2)

## 04. html 페이지 파싱
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
for pageloop in range(10) :
    crawl_title()
    ## 06. 다음 페이지 클릭
    driver.find_element(by=By.XPATH, value =f'//*[@id="paging"]/a[{pageloop+1}]')

## 07. page 1-10까지 제목 출력
for idx, title in enumerate(title_list ,1) :
    print(f'{idx}. {title.text}')
# Out:
# 1. ‘LTV 80%·50년 초장기 모기지’…새 정부, 민생안정대책 발표
# 2. 직방, 전국 3만2952가구 6월 분양예정
# 3. 7월 곡물 재앙 불안감에 국내 곡물주 동반 상승
# 4. 코로나19 소상공인 손실보전금 정오부터 신청…오후 3시부터 지급
# 5. 국토부, 버스기사 1인당 300만원 지원 등 2차 추경 확정
# 6. 6월, 전국 3만여 가구 분양…"분상제 완화 기대에 분양 미룰수도"
# 7. 신고가 수십곳 쏟아진 일산·조용한 평촌…'1기 신도시' 집값 상승 온도차 왜?
# 8. 오늘부터 '최대 1000만원' 소상공인 손실보전금 지급…"신속지급 실시"
# 9. 김건희 여사 사진, 롯데온서 사라진 이유는? [언박싱]
# 10. [시사이슈 찬반토론] 정부의 집값 개입 분양가 상한제, '시장 안정'에 도움 되나
# 11. 불확실성 시대, 방산·굴삭기株 주목
# 12. 김지만이 낳고 이재웅이 키운 ‘쏘카’… IPO 결실은 박재욱이 거둔다
# 13. 이규호가 이끄는 코오롱글로벌 ‘수입차’, 건설 매출 첫 추월
# 14. [어느 강소기업의 유리천장] 관행이라는 ‘규제의 장벽’에 신음하는 혁신기업
# 15. ‘투자의 전설’ 남석관 “LG에너지솔루션 40만 원이 바닥”
# 16. 신재생에너지 발전비중 7% 넘었다…사상 최고
# 17. 카뱅 “주담대 연체되면 캠코에 매각해 임차거주 가능”…캠코와 맞손
# 18. 경기도 시흥시, '힐스테이트 시흥대야역' 특별분양 진행 중
# 19. [은행원 잔혹사①] "칼로 찌르겠다 수차례 협박"…눈물의 메모
# 20. 공정시장가액비율 낮춰 종부세 2020년 수준으로 환원
# 21. ‘LTV 80%·50년 초장기 모기지’…새 정부, 민생안정대책 발표
# 22. 직방, 전국 3만2952가구 6월 분양예정
# 23. 7월 곡물 재앙 불안감에 국내 곡물주 동반 상승
# 24. 코로나19 소상공인 손실보전금 정오부터 신청…오후 3시부터 지급
# 25. 국토부, 버스기사 1인당 300만원 지원 등 2차 추경 확정
# ...
